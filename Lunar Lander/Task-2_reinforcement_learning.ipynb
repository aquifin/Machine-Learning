# %% [markdown]
# # Task-2 Reinforcement Learning

# %% [markdown]
# ### Import Packages

# %%
import numpy as np
import gym

from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten
from keras.optimizers import Adam

from rl.agents.dqn import DQNAgent
from rl.policy import BoltzmannQPolicy, EpsGreedyQPolicy
from rl.memory import SequentialMemory
from rl.callbacks import Callback
import random
# Out:
# Using TensorFlow backend.

# %%
# Path environment changed to make things work properly
# export DYLD_FALLBACK_LIBRARY_PATH=$DYLD_FALLBACK_LIBRARY_PATH:/usr/lib

ENV_NAME = 'LunarLander-v2'


# Get the environment and extract the number of actions.
env = gym.make(ENV_NAME)
np.random.seed(123)
env.seed(123)
nb_actions = env.action_space.n

# Next, we build a very simple model.

model = Sequential()
model.add(Flatten(input_shape=(1,) + env.observation_space.shape))
model.add(Dense(40))
model.add(Activation('relu'))
model.add(Dense(40))
model.add(Activation('relu'))
model.add(Dense(nb_actions))
model.add(Activation('linear'))
print(model.summary())



# Finally, we configure and compile our agent. You can use every built-in Keras optimizer and
# even the metrics!
memory = SequentialMemory(limit=50000, window_length=1)
policy = EpsGreedyQPolicy(eps=1.0)

#Call back for the begin and end of the episode
class OnBegin(Callback):
    def __init__(self, eps_poilcy, decay_rate=0.95):
        self.eps_poilcy = eps_poilcy
        self.decay_rate = decay_rate
    def on_episode_begin(self, episode, logs={}):
        self.eps_poilcy.eps *= self.decay_rate
        print ('eps = %s' % self.eps_poilcy.eps)

class OnEnd(Callback):
    def __init__(self, nb_episodes=4000, avgwindow=20):
        self.rewards = np.zeros(nb_episodes) - 1000.0
        self.X = np.arange(1, nb_episodes+1)
        self.avgrewards = np.zeros(nb_episodes) - 1000.0
        self.avgwindow = avgwindow
        self.rewardbuf = []
        self.episode = 0
        self.nb_episodes = nb_episodes
        
    def on_episode_end(self, episode, logs):
        if self.episode >= self.nb_episodes:
            return
        rw = logs['episode_reward']
        self.rewardbuf.append(rw)
        if len(self.rewardbuf) > self.avgwindow:
            del self.rewardbuf[0]
        self.rewards[self.episode] = rw
        self.avgrewards[self.episode] = np.mean(self.rewardbuf)
        self.episode += 1
     

dqn = DQNAgent(model=model, nb_actions=nb_actions, memory=memory, nb_steps_warmup=10,
               target_model_update=1e-2, policy=policy, enable_double_dqn=False)
dqn.compile(Adam(lr=0.002, decay=2.25e-05), metrics=['mae'])

cbs = [OnBegin(eps_poilcy=policy, decay_rate=0.975)]
cbs += [OnEnd(nb_episodes=4000, avgwindow=20)]

# Okay, now it's time to learn something! We visualize the training here for show, but this
# slows down training quite a lot. You can always safely abort the training prematurely using
# Ctrl + C.

dqn.fit(env, nb_steps=50000, visualize=False, verbose=2,callbacks=cbs)

# After training is done, we save the final weights.
dqn.save_weights('dqn_{}_weights.h5f'.format(ENV_NAME), overwrite=True)

# Finally, evaluate our algorithm for 5 episodes.
dqn.test(env, nb_episodes=5, visualize=True)
# Out:
# WARNING:tensorflow:From C:\Users\AUF\Anaconda3\envs\tflow\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 8)                 0
# _________________________________________________________________
# dense_1 (Dense)              (None, 40)                360
# _________________________________________________________________
# activation_1 (Activation)    (None, 40)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 40)                1640
# _________________________________________________________________
# activation_2 (Activation)    (None, 40)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 4)                 164
# _________________________________________________________________
# activation_3 (Activation)    (None, 4)                 0
# =================================================================
# Total params: 2,164
# Trainable params: 2,164
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training for 50000 steps ...
# eps = 0.975
# WARNING:tensorflow:From C:\Users\AUF\Anaconda3\envs\tflow\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# C:\Users\AUF\AppData\Roaming\Python\Python37\site-packages\rl\memory.py:39: UserWarning: Not enough entries to sample without replacement. Consider increasing your warm-up phase to avoid oversampling!
#   warnings.warn('Not enough entries to sample without replacement. Consider increasing your warm-up phase to avoid oversampling!')
#     71/50000: episode: 1, duration: 0.763s, episode steps: 71, steps per second: 93, episode reward: -135.040, mean reward: -1.902 [-100.000, 25.512], mean action: 1.507 [0.000, 3.000], mean observation: 0.023 [-1.594, 2.100], loss: 0.788042, mean_absolute_error: 0.800852, mean_q: 1.099213
# eps = 0.9506249999999999
#    196/50000: episode: 2, duration: 0.252s, episode steps: 125, steps per second: 497, episode reward: -201.706, mean reward: -1.614 [-100.000, 6.187], mean action: 1.344 [0.000, 3.000], mean observation: 0.230 [-1.640, 3.910], loss: 50.067806, mean_absolute_error: 1.318214, mean_q: 1.423686
# eps = 0.9268593749999999
#    290/50000: episode: 3, duration: 0.182s, episode steps: 94, steps per second: 515, episode reward: -161.535, mean reward: -1.718 [-100.000, 38.805], mean action: 1.447 [0.000, 3.000], mean observation: -0.034 [-1.431, 5.928], loss: 37.504807, mean_absolute_error: 1.575816, mean_q: 1.870928
# eps = 0.9036878906249999
#    380/50000: episode: 4, duration: 0.186s, episode steps: 90, steps per second: 484, episode reward: -287.985, mean reward: -3.200 [-100.000, 109.341], mean action: 1.711 [0.000, 3.000], mean observation: -0.004 [-3.126, 1.405], loss: 51.354824, mean_absolute_error: 1.801683, mean_q: 2.335705
# eps = 0.8810956933593749
#    441/50000: episode: 5, duration: 0.120s, episode steps: 61, steps per second: 508, episode reward: -50.100, mean reward: -0.821 [-100.000, 55.021], mean action: 1.377 [0.000, 3.000], mean observation: 0.015 [-1.375, 4.268], loss: 89.053528, mean_absolute_error: 2.033297, mean_q: 2.243282
# eps = 0.8590683010253904
#    513/50000: episode: 6, duration: 0.156s, episode steps: 72, steps per second: 461, episode reward: -110.508, mean reward: -1.535 [-100.000, 6.423], mean action: 1.292 [0.000, 3.000], mean observation: 0.023 [-1.292, 1.395], loss: 68.690765, mean_absolute_error: 2.305067, mean_q: 3.185666
# eps = 0.8375915934997556
#    593/50000: episode: 7, duration: 0.158s, episode steps: 80, steps per second: 508, episode reward: -67.959, mean reward: -0.849 [-100.000, 8.738], mean action: 1.800 [0.000, 3.000], mean observation: -0.009 [-1.149, 3.794], loss: 60.262878, mean_absolute_error: 3.692969, mean_q: 5.748845
# eps = 0.8166518036622618
#    676/50000: episode: 8, duration: 0.177s, episode steps: 83, steps per second: 470, episode reward: -457.035, mean reward: -5.506 [-100.000, 0.686], mean action: 1.482 [0.000, 3.000], mean observation: 0.041 [-1.877, 2.134], loss: 58.994770, mean_absolute_error: 4.318487, mean_q: 5.307166
# eps = 0.7962355085707052
#    790/50000: episode: 9, duration: 0.234s, episode steps: 114, steps per second: 487, episode reward: -30.516, mean reward: -0.268 [-100.000, 14.213], mean action: 1.395 [0.000, 3.000], mean observation: -0.028 [-0.916, 1.426], loss: 54.334488, mean_absolute_error: 4.741461, mean_q: 5.492818
# eps = 0.7763296208564376
#    918/50000: episode: 10, duration: 0.273s, episode steps: 128, steps per second: 469, episode reward: -32.483, mean reward: -0.254 [-100.000, 17.530], mean action: 1.711 [0.000, 3.000], mean observation: 0.101 [-3.115, 1.532], loss: 47.975555, mean_absolute_error: 5.266404, mean_q: 6.483963
# eps = 0.7569213803350267
#   1032/50000: episode: 11, duration: 0.238s, episode steps: 114, steps per second: 480, episode reward: -287.560, mean reward: -2.522 [-100.000, 3.221], mean action: 1.860 [0.000, 3.000], mean observation: -0.094 [-1.870, 1.468], loss: 46.225433, mean_absolute_error: 6.524586, mean_q: 7.321791
# eps = 0.7379983458266509
#   1101/50000: episode: 12, duration: 0.140s, episode steps: 69, steps per second: 491, episode reward: -58.220, mean reward: -0.844 [-100.000, 8.786], mean action: 1.652 [0.000, 3.000], mean observation: -0.133 [-4.233, 1.386], loss: 31.752951, mean_absolute_error: 7.563758, mean_q: 7.486764
# eps = 0.7195483871809846
#   1226/50000: episode: 13, duration: 0.301s, episode steps: 125, steps per second: 415, episode reward: -92.115, mean reward: -0.737 [-100.000, 12.289], mean action: 1.496 [0.000, 3.000], mean observation: -0.002 [-1.035, 3.805], loss: 28.747196, mean_absolute_error: 8.327999, mean_q: 8.534224
# eps = 0.70155967750146
#   1355/50000: episode: 14, duration: 0.289s, episode steps: 129, steps per second: 447, episode reward: -286.730, mean reward: -2.223 [-100.000, 13.162], mean action: 1.287 [0.000, 3.000], mean observation: 0.134 [-1.553, 4.427], loss: 26.187391, mean_absolute_error: 9.448473, mean_q: 9.889981
# eps = 0.6840206855639235
#   1500/50000: episode: 15, duration: 0.304s, episode steps: 145, steps per second: 477, episode reward: -82.841, mean reward: -0.571 [-100.000, 14.410], mean action: 1.738 [0.000, 3.000], mean observation: -0.005 [-0.832, 2.595], loss: 18.715904, mean_absolute_error: 10.222644, mean_q: 9.961908
# eps = 0.6669201684248254
#   1666/50000: episode: 16, duration: 0.340s, episode steps: 166, steps per second: 488, episode reward: -151.566, mean reward: -0.913 [-100.000, 37.992], mean action: 1.639 [0.000, 3.000], mean observation: 0.087 [-1.137, 3.706], loss: 18.957232, mean_absolute_error: 10.987100, mean_q: 10.621102
# eps = 0.6502471642142047
#   1760/50000: episode: 17, duration: 0.180s, episode steps: 94, steps per second: 522, episode reward: -143.732, mean reward: -1.529 [-100.000, 10.388], mean action: 1.702 [0.000, 3.000], mean observation: -0.048 [-3.347, 1.403], loss: 17.681395, mean_absolute_error: 11.835406, mean_q: 10.701142
# eps = 0.6339909851088495
#   1867/50000: episode: 18, duration: 0.228s, episode steps: 107, steps per second: 470, episode reward: -276.879, mean reward: -2.588 [-100.000, 2.504], mean action: 1.458 [0.000, 3.000], mean observation: 0.241 [-4.166, 1.656], loss: 15.156440, mean_absolute_error: 12.789977, mean_q: 11.316373
# eps = 0.6181412104811282
#   1995/50000: episode: 19, duration: 0.263s, episode steps: 128, steps per second: 487, episode reward: -169.423, mean reward: -1.324 [-100.000, 7.715], mean action: 1.367 [0.000, 3.000], mean observation: 0.169 [-1.378, 1.420], loss: 15.299329, mean_absolute_error: 13.392788, mean_q: 11.625225
# eps = 0.6026876802191
#   2084/50000: episode: 20, duration: 0.174s, episode steps: 89, steps per second: 511, episode reward: -144.997, mean reward: -1.629 [-100.000, 7.585], mean action: 1.753 [0.000, 3.000], mean observation: -0.092 [-1.167, 2.226], loss: 15.328922, mean_absolute_error: 13.676928, mean_q: 12.289281
# eps = 0.5876204882136226
#   2209/50000: episode: 21, duration: 0.255s, episode steps: 125, steps per second: 490, episode reward: -150.654, mean reward: -1.205 [-100.000, 54.730], mean action: 1.416 [0.000, 3.000], mean observation: 0.191 [-1.626, 1.490], loss: 14.298073, mean_absolute_error: 14.493432, mean_q: 12.797675
# eps = 0.572929976008282
#   2340/50000: episode: 22, duration: 0.270s, episode steps: 131, steps per second: 485, episode reward: -38.915, mean reward: -0.297 [-100.000, 40.584], mean action: 1.534 [0.000, 3.000], mean observation: 0.116 [-1.846, 1.390], loss: 14.742615, mean_absolute_error: 15.547938, mean_q: 12.490173
# eps = 0.558606726608075
#   2485/50000: episode: 23, duration: 0.307s, episode steps: 145, steps per second: 473, episode reward: 14.942, mean reward: 0.103 [-100.000, 16.502], mean action: 1.745 [0.000, 3.000], mean observation: 0.024 [-1.018, 1.394], loss: 18.503643, mean_absolute_error: 16.005831, mean_q: 12.368965
# eps = 0.5446415584428731
#   2598/50000: episode: 24, duration: 0.224s, episode steps: 113, steps per second: 505, episode reward: -177.063, mean reward: -1.567 [-100.000, 5.492], mean action: 1.761 [0.000, 3.000], mean observation: 0.160 [-0.835, 2.621], loss: 13.748791, mean_absolute_error: 16.069641, mean_q: 13.266715
# eps = 0.5310255194818012
#   2816/50000: episode: 25, duration: 0.453s, episode steps: 218, steps per second: 482, episode reward: -145.666, mean reward: -0.668 [-100.000, 14.556], mean action: 1.583 [0.000, 3.000], mean observation: 0.104 [-1.508, 1.553], loss: 11.116354, mean_absolute_error: 17.332737, mean_q: 12.914398
# eps = 0.5177498814947562
#   2972/50000: episode: 26, duration: 0.324s, episode steps: 156, steps per second: 482, episode reward: -21.192, mean reward: -0.136 [-100.000, 57.818], mean action: 1.603 [0.000, 3.000], mean observation: 0.146 [-0.762, 1.431], loss: 8.079692, mean_absolute_error: 18.079018, mean_q: 12.402020
# eps = 0.5048061344573873
#   3244/50000: episode: 27, duration: 0.569s, episode steps: 272, steps per second: 478, episode reward: 9.594, mean reward: 0.035 [-100.000, 17.270], mean action: 1.779 [0.000, 3.000], mean observation: 0.020 [-0.575, 1.411], loss: 12.091181, mean_absolute_error: 19.073853, mean_q: 13.015141
# eps = 0.49218598109595263
#   3392/50000: episode: 28, duration: 0.297s, episode steps: 148, steps per second: 499, episode reward: -42.417, mean reward: -0.287 [-100.000, 11.954], mean action: 1.709 [0.000, 3.000], mean observation: -0.006 [-1.115, 3.962], loss: 9.276083, mean_absolute_error: 19.593243, mean_q: 13.178141
# eps = 0.4798813315685538
#   4083/50000: episode: 29, duration: 1.988s, episode steps: 691, steps per second: 348, episode reward: -312.939, mean reward: -0.453 [-100.000, 17.155], mean action: 1.773 [0.000, 3.000], mean observation: 0.052 [-1.024, 1.664], loss: 7.499293, mean_absolute_error: 21.033991, mean_q: 13.237780
# eps = 0.4678842982793399
#   4275/50000: episode: 30, duration: 0.403s, episode steps: 192, steps per second: 476, episode reward: -37.389, mean reward: -0.195 [-100.000, 16.881], mean action: 1.703 [0.000, 3.000], mean observation: 0.006 [-1.135, 1.396], loss: 6.386728, mean_absolute_error: 22.796846, mean_q: 11.861244
# eps = 0.4561871908223564
#   4631/50000: episode: 31, duration: 0.781s, episode steps: 356, steps per second: 456, episode reward: -68.158, mean reward: -0.191 [-100.000, 17.124], mean action: 1.747 [0.000, 3.000], mean observation: 0.075 [-0.840, 1.615], loss: 8.098087, mean_absolute_error: 23.426775, mean_q: 12.927411
# eps = 0.4447825110517975
#   4911/50000: episode: 32, duration: 0.594s, episode steps: 280, steps per second: 471, episode reward: -79.664, mean reward: -0.285 [-100.000, 12.517], mean action: 1.761 [0.000, 3.000], mean observation: 0.061 [-1.535, 1.541], loss: 9.009537, mean_absolute_error: 24.059786, mean_q: 13.632682
# eps = 0.43366294827550256
#   5015/50000: episode: 33, duration: 0.209s, episode steps: 104, steps per second: 497, episode reward: -56.129, mean reward: -0.540 [-100.000, 17.807], mean action: 1.779 [0.000, 3.000], mean observation: 0.140 [-0.828, 1.389], loss: 10.493363, mean_absolute_error: 24.628845, mean_q: 14.756883
# eps = 0.42282137456861496
#   5306/50000: episode: 34, duration: 0.610s, episode steps: 291, steps per second: 477, episode reward: -13.827, mean reward: -0.048 [-100.000, 16.194], mean action: 1.670 [0.000, 3.000], mean observation: -0.050 [-0.684, 1.497], loss: 11.609441, mean_absolute_error: 25.085417, mean_q: 15.867738
# eps = 0.41225084020439956
#   5498/50000: episode: 35, duration: 0.389s, episode steps: 192, steps per second: 493, episode reward: -30.665, mean reward: -0.160 [-100.000, 13.828], mean action: 1.760 [0.000, 3.000], mean observation: 0.036 [-1.096, 1.436], loss: 9.049893, mean_absolute_error: 25.304140, mean_q: 17.558302
# eps = 0.40194456919928956
#   5930/50000: episode: 36, duration: 1.012s, episode steps: 432, steps per second: 427, episode reward: -102.527, mean reward: -0.237 [-100.000, 6.082], mean action: 1.750 [0.000, 3.000], mean observation: 0.154 [-0.404, 2.223], loss: 7.996419, mean_absolute_error: 26.023569, mean_q: 18.198845
# eps = 0.3918959549693073
#   6183/50000: episode: 37, duration: 0.550s, episode steps: 253, steps per second: 460, episode reward: -94.954, mean reward: -0.375 [-100.000, 4.596], mean action: 1.838 [0.000, 3.000], mean observation: -0.105 [-1.001, 1.392], loss: 9.100073, mean_absolute_error: 27.039942, mean_q: 19.577036
# eps = 0.3820985560950746
#   6747/50000: episode: 38, duration: 1.339s, episode steps: 564, steps per second: 421, episode reward: -275.350, mean reward: -0.488 [-100.000, 13.586], mean action: 1.812 [0.000, 3.000], mean observation: 0.155 [-0.728, 1.426], loss: 8.394334, mean_absolute_error: 27.276449, mean_q: 20.406960
# eps = 0.37254609219269774
#   7008/50000: episode: 39, duration: 0.632s, episode steps: 261, steps per second: 413, episode reward: -207.429, mean reward: -0.795 [-100.000, 30.458], mean action: 1.801 [0.000, 3.000], mean observation: -0.116 [-1.666, 1.408], loss: 9.448123, mean_absolute_error: 27.652138, mean_q: 21.050688
# eps = 0.3632324398878803
#   7587/50000: episode: 40, duration: 1.464s, episode steps: 579, steps per second: 395, episode reward: -238.173, mean reward: -0.411 [-100.000, 11.904], mean action: 1.665 [0.000, 3.000], mean observation: 0.051 [-0.790, 1.400], loss: 7.590549, mean_absolute_error: 28.731592, mean_q: 21.762917
# eps = 0.35415162889068325
#   7717/50000: episode: 41, duration: 0.264s, episode steps: 130, steps per second: 492, episode reward: -18.988, mean reward: -0.146 [-100.000, 11.601], mean action: 1.731 [0.000, 3.000], mean observation: -0.036 [-0.709, 1.392], loss: 6.681723, mean_absolute_error: 28.813208, mean_q: 21.718397
# eps = 0.34529783816841614
#   7858/50000: episode: 42, duration: 0.283s, episode steps: 141, steps per second: 498, episode reward: -50.939, mean reward: -0.361 [-100.000, 14.686], mean action: 1.738 [0.000, 3.000], mean observation: -0.043 [-0.801, 2.778], loss: 8.623606, mean_absolute_error: 29.570261, mean_q: 23.459040
# eps = 0.3366653922142057
#   8858/50000: episode: 43, duration: 3.522s, episode steps: 1000, steps per second: 284, episode reward: -28.425, mean reward: -0.028 [-4.932, 4.555], mean action: 1.812 [0.000, 3.000], mean observation: 0.069 [-0.417, 1.558], loss: 7.577549, mean_absolute_error: 29.926279, mean_q: 23.897184
# eps = 0.32824875740885057
#   8977/50000: episode: 44, duration: 0.242s, episode steps: 119, steps per second: 491, episode reward: -11.502, mean reward: -0.097 [-100.000, 17.206], mean action: 1.681 [0.000, 3.000], mean observation: 0.175 [-1.235, 1.393], loss: 8.706625, mean_absolute_error: 29.514801, mean_q: 24.938324
# eps = 0.3200425384736293
#   9977/50000: episode: 45, duration: 3.119s, episode steps: 1000, steps per second: 321, episode reward: -27.279, mean reward: -0.027 [-21.142, 21.467], mean action: 1.758 [0.000, 3.000], mean observation: 0.023 [-1.267, 1.392], loss: 6.692845, mean_absolute_error: 29.851067, mean_q: 24.500593
# eps = 0.3120414750117885
#  10856/50000: episode: 46, duration: 2.382s, episode steps: 879, steps per second: 369, episode reward: -274.510, mean reward: -0.312 [-100.000, 11.632], mean action: 1.720 [0.000, 3.000], mean observation: 0.003 [-1.002, 1.410], loss: 7.014186, mean_absolute_error: 29.459702, mean_q: 23.908161
# eps = 0.3042404381364938
#  11047/50000: episode: 47, duration: 0.389s, episode steps: 191, steps per second: 491, episode reward: -135.772, mean reward: -0.711 [-100.000, 3.215], mean action: 1.707 [0.000, 3.000], mean observation: 0.264 [-0.402, 1.410], loss: 5.238544, mean_absolute_error: 28.580948, mean_q: 23.573008
# eps = 0.2966344271830815
#  12047/50000: episode: 48, duration: 2.605s, episode steps: 1000, steps per second: 384, episode reward: -122.156, mean reward: -0.122 [-13.502, 15.628], mean action: 1.736 [0.000, 3.000], mean observation: -0.024 [-0.573, 1.409], loss: 6.410281, mean_absolute_error: 28.478174, mean_q: 23.564625
# eps = 0.2892185665035044
#  13047/50000: episode: 49, duration: 3.100s, episode steps: 1000, steps per second: 323, episode reward: -26.176, mean reward: -0.026 [-13.395, 12.542], mean action: 1.710 [0.000, 3.000], mean observation: 0.015 [-0.605, 1.406], loss: 5.348719, mean_absolute_error: 28.075758, mean_q: 23.498863
# eps = 0.2819881023409168
#  14047/50000: episode: 50, duration: 2.617s, episode steps: 1000, steps per second: 382, episode reward: -85.922, mean reward: -0.086 [-14.484, 18.138], mean action: 1.807 [0.000, 3.000], mean observation: 0.022 [-0.474, 1.415], loss: 5.312617, mean_absolute_error: 27.116438, mean_q: 23.242973
# eps = 0.27493839978239387
#  14235/50000: episode: 51, duration: 0.374s, episode steps: 188, steps per second: 502, episode reward: -56.917, mean reward: -0.303 [-100.000, 24.733], mean action: 1.612 [0.000, 3.000], mean observation: -0.022 [-1.048, 1.988], loss: 5.030166, mean_absolute_error: 26.973877, mean_q: 22.586815
# eps = 0.268064939787834
#  15235/50000: episode: 52, duration: 3.293s, episode steps: 1000, steps per second: 304, episode reward: 43.312, mean reward: 0.043 [-19.920, 27.272], mean action: 1.725 [0.000, 3.000], mean observation: 0.075 [-0.777, 1.463], loss: 6.126332, mean_absolute_error: 26.928549, mean_q: 23.098801
# eps = 0.2613633162931382
#  16235/50000: episode: 53, duration: 3.047s, episode steps: 1000, steps per second: 328, episode reward: -26.914, mean reward: -0.027 [-21.156, 21.510], mean action: 1.772 [0.000, 3.000], mean observation: 0.025 [-1.002, 1.404], loss: 5.157484, mean_absolute_error: 26.161810, mean_q: 22.484930
# eps = 0.2548292333858097
#  17235/50000: episode: 54, duration: 3.436s, episode steps: 1000, steps per second: 291, episode reward: -84.187, mean reward: -0.084 [-21.286, 10.696], mean action: 1.694 [0.000, 3.000], mean observation: -0.002 [-0.563, 1.410], loss: 5.712145, mean_absolute_error: 25.383011, mean_q: 22.877956
# eps = 0.24845850255116445
#  18235/50000: episode: 55, duration: 3.227s, episode steps: 1000, steps per second: 310, episode reward: -8.220, mean reward: -0.008 [-5.109, 4.992], mean action: 1.788 [0.000, 3.000], mean observation: 0.093 [-0.427, 2.067], loss: 6.133233, mean_absolute_error: 24.979727, mean_q: 24.075621
# eps = 0.24224703998738534
#  19184/50000: episode: 56, duration: 2.553s, episode steps: 949, steps per second: 372, episode reward: -108.617, mean reward: -0.114 [-100.000, 14.619], mean action: 1.737 [0.000, 3.000], mean observation: 0.012 [-0.694, 1.395], loss: 5.935699, mean_absolute_error: 24.375511, mean_q: 24.109104
# eps = 0.2361908639877007
#  20142/50000: episode: 57, duration: 2.414s, episode steps: 958, steps per second: 397, episode reward: -269.897, mean reward: -0.282 [-100.000, 4.282], mean action: 1.627 [0.000, 3.000], mean observation: -0.019 [-1.002, 1.410], loss: 5.498909, mean_absolute_error: 23.897566, mean_q: 24.294294
# eps = 0.23028609238800818
#  20455/50000: episode: 58, duration: 0.681s, episode steps: 313, steps per second: 459, episode reward: -219.818, mean reward: -0.702 [-100.000, 3.411], mean action: 1.856 [0.000, 3.000], mean observation: 0.303 [-0.386, 1.834], loss: 4.304248, mean_absolute_error: 23.053289, mean_q: 23.536369
# eps = 0.22452894007830798
#  21455/50000: episode: 59, duration: 3.119s, episode steps: 1000, steps per second: 321, episode reward: -41.414, mean reward: -0.041 [-4.999, 5.479], mean action: 1.636 [0.000, 3.000], mean observation: 0.009 [-0.581, 1.514], loss: 5.511797, mean_absolute_error: 23.302317, mean_q: 24.823334
# eps = 0.21891571657635028
#  22112/50000: episode: 60, duration: 1.670s, episode steps: 657, steps per second: 393, episode reward: -86.929, mean reward: -0.132 [-100.000, 17.112], mean action: 1.720 [0.000, 3.000], mean observation: -0.004 [-1.019, 1.402], loss: 5.591028, mean_absolute_error: 23.382494, mean_q: 24.890896
# eps = 0.21344282366194153
#  22453/50000: episode: 61, duration: 0.716s, episode steps: 341, steps per second: 476, episode reward: -35.708, mean reward: -0.105 [-100.000, 25.737], mean action: 1.510 [0.000, 3.000], mean observation: 0.007 [-0.929, 1.538], loss: 3.594362, mean_absolute_error: 23.127798, mean_q: 25.067612
# eps = 0.208106753070393
#  22887/50000: episode: 62, duration: 1.057s, episode steps: 434, steps per second: 411, episode reward: -63.222, mean reward: -0.146 [-100.000, 12.849], mean action: 1.864 [0.000, 3.000], mean observation: 0.046 [-0.689, 1.422], loss: 6.025796, mean_absolute_error: 23.193584, mean_q: 25.010710
# eps = 0.20290408424363318
#  23887/50000: episode: 63, duration: 2.521s, episode steps: 1000, steps per second: 397, episode reward: -73.955, mean reward: -0.074 [-7.064, 13.741], mean action: 1.680 [0.000, 3.000], mean observation: -0.025 [-0.543, 1.435], loss: 5.881247, mean_absolute_error: 22.890640, mean_q: 25.205612
# eps = 0.19783148213754234
#  24887/50000: episode: 64, duration: 2.600s, episode steps: 1000, steps per second: 385, episode reward: -20.516, mean reward: -0.021 [-19.330, 21.068], mean action: 1.753 [0.000, 3.000], mean observation: 0.033 [-0.923, 1.470], loss: 5.426702, mean_absolute_error: 22.544073, mean_q: 25.056070
# eps = 0.19288569508410378
#  25887/50000: episode: 65, duration: 3.002s, episode steps: 1000, steps per second: 333, episode reward: -16.366, mean reward: -0.016 [-4.871, 4.717], mean action: 1.631 [0.000, 3.000], mean observation: 0.029 [-0.447, 1.390], loss: 5.985208, mean_absolute_error: 22.199404, mean_q: 24.708086
# eps = 0.18806355270700117
#  26244/50000: episode: 66, duration: 0.772s, episode steps: 357, steps per second: 462, episode reward: -82.222, mean reward: -0.230 [-100.000, 15.741], mean action: 1.655 [0.000, 3.000], mean observation: -0.048 [-0.807, 1.412], loss: 5.541365, mean_absolute_error: 22.573540, mean_q: 25.012001
# eps = 0.18336196388932613
#  27244/50000: episode: 67, duration: 3.391s, episode steps: 1000, steps per second: 295, episode reward: -17.661, mean reward: -0.018 [-19.641, 14.812], mean action: 1.582 [0.000, 3.000], mean observation: -0.001 [-0.627, 1.439], loss: 5.167568, mean_absolute_error: 22.162975, mean_q: 25.008772
# eps = 0.17877791479209298
#  28244/50000: episode: 68, duration: 2.693s, episode steps: 1000, steps per second: 371, episode reward: -108.602, mean reward: -0.109 [-4.444, 5.518], mean action: 1.590 [0.000, 3.000], mean observation: -0.022 [-0.648, 1.411], loss: 5.463583, mean_absolute_error: 21.965891, mean_q: 24.997330
# eps = 0.17430846692229066
#  29244/50000: episode: 69, duration: 2.939s, episode steps: 1000, steps per second: 340, episode reward: -32.044, mean reward: -0.032 [-5.173, 4.854], mean action: 1.692 [0.000, 3.000], mean observation: 0.030 [-0.624, 1.425], loss: 5.537887, mean_absolute_error: 21.837082, mean_q: 24.888756
# eps = 0.1699507552492334
#  30244/50000: episode: 70, duration: 3.469s, episode steps: 1000, steps per second: 288, episode reward: 6.816, mean reward: 0.007 [-13.068, 10.889], mean action: 1.672 [0.000, 3.000], mean observation: 0.028 [-0.694, 1.416], loss: 5.347376, mean_absolute_error: 21.781298, mean_q: 25.374832
# eps = 0.16570198636800254
#  31244/50000: episode: 71, duration: 2.717s, episode steps: 1000, steps per second: 368, episode reward: 8.073, mean reward: 0.008 [-5.174, 4.848], mean action: 1.483 [0.000, 3.000], mean observation: -0.016 [-0.758, 1.392], loss: 5.514898, mean_absolute_error: 21.558899, mean_q: 25.190718
# eps = 0.16155943670880246
#  32244/50000: episode: 72, duration: 2.832s, episode steps: 1000, steps per second: 353, episode reward: -35.459, mean reward: -0.035 [-4.523, 4.704], mean action: 1.706 [0.000, 3.000], mean observation: -0.064 [-0.980, 1.419], loss: 5.411225, mean_absolute_error: 21.242661, mean_q: 24.911232
# eps = 0.1575204507910824
#  32454/50000: episode: 73, duration: 0.428s, episode steps: 210, steps per second: 490, episode reward: -48.596, mean reward: -0.231 [-100.000, 11.362], mean action: 1.495 [0.000, 3.000], mean observation: -0.025 [-1.032, 1.443], loss: 5.392868, mean_absolute_error: 21.191685, mean_q: 25.303375
# eps = 0.15358243952130535
#  33454/50000: episode: 74, duration: 3.125s, episode steps: 1000, steps per second: 320, episode reward: -14.859, mean reward: -0.015 [-4.907, 4.044], mean action: 1.721 [0.000, 3.000], mean observation: 0.055 [-0.478, 1.489], loss: 5.810876, mean_absolute_error: 21.003227, mean_q: 24.940020
# eps = 0.1497428785332727
#  34454/50000: episode: 75, duration: 2.997s, episode steps: 1000, steps per second: 334, episode reward: 6.337, mean reward: 0.006 [-4.559, 5.536], mean action: 1.671 [0.000, 3.000], mean observation: 0.022 [-0.702, 1.391], loss: 5.834643, mean_absolute_error: 20.998772, mean_q: 24.974184
# eps = 0.14599930656994087
#  35454/50000: episode: 76, duration: 2.614s, episode steps: 1000, steps per second: 383, episode reward: -53.257, mean reward: -0.053 [-4.435, 4.661], mean action: 1.867 [0.000, 3.000], mean observation: 0.096 [-0.293, 1.419], loss: 5.562866, mean_absolute_error: 21.071440, mean_q: 25.428303
# eps = 0.14234932390569235
#  36454/50000: episode: 77, duration: 2.936s, episode steps: 1000, steps per second: 341, episode reward: -13.202, mean reward: -0.013 [-4.308, 4.452], mean action: 1.936 [0.000, 3.000], mean observation: 0.085 [-0.471, 1.393], loss: 5.566734, mean_absolute_error: 21.079323, mean_q: 25.739193
# eps = 0.13879059080805004
#  36962/50000: episode: 78, duration: 1.150s, episode steps: 508, steps per second: 442, episode reward: 169.563, mean reward: 0.334 [-10.674, 100.000], mean action: 2.157 [0.000, 3.000], mean observation: 0.001 [-0.704, 1.409], loss: 5.244551, mean_absolute_error: 21.520725, mean_q: 26.569807
# eps = 0.13532082603784878
#  37962/50000: episode: 79, duration: 3.264s, episode steps: 1000, steps per second: 306, episode reward: -42.839, mean reward: -0.043 [-5.550, 4.708], mean action: 1.888 [0.000, 3.000], mean observation: 0.098 [-0.480, 1.416], loss: 6.522413, mean_absolute_error: 21.613592, mean_q: 26.912512
# eps = 0.13193780538690256
#  38962/50000: episode: 80, duration: 3.075s, episode steps: 1000, steps per second: 325, episode reward: -33.906, mean reward: -0.034 [-4.608, 5.226], mean action: 1.719 [0.000, 3.000], mean observation: 0.048 [-0.665, 1.405], loss: 4.957975, mean_absolute_error: 21.615864, mean_q: 26.855505
# eps = 0.12863936025223
#  39962/50000: episode: 81, duration: 3.193s, episode steps: 1000, steps per second: 313, episode reward: -30.554, mean reward: -0.031 [-4.475, 5.083], mean action: 1.905 [0.000, 3.000], mean observation: 0.071 [-0.605, 1.397], loss: 5.651938, mean_absolute_error: 21.670254, mean_q: 27.063391
# eps = 0.12542337624592423
#  40962/50000: episode: 82, duration: 3.356s, episode steps: 1000, steps per second: 298, episode reward: -57.718, mean reward: -0.058 [-4.749, 4.509], mean action: 1.488 [0.000, 3.000], mean observation: 0.008 [-0.408, 1.406], loss: 5.335782, mean_absolute_error: 21.542063, mean_q: 27.346405
# eps = 0.12228779183977612
#  41962/50000: episode: 83, duration: 3.153s, episode steps: 1000, steps per second: 317, episode reward: -6.300, mean reward: -0.006 [-4.832, 5.604], mean action: 1.521 [0.000, 3.000], mean observation: 0.048 [-0.679, 1.482], loss: 5.161237, mean_absolute_error: 22.222054, mean_q: 28.289217
# eps = 0.11923059704378171
#  42208/50000: episode: 84, duration: 0.523s, episode steps: 246, steps per second: 470, episode reward: -61.636, mean reward: -0.251 [-100.000, 18.373], mean action: 1.451 [0.000, 3.000], mean observation: 0.105 [-1.746, 1.394], loss: 5.275346, mean_absolute_error: 22.351042, mean_q: 28.379578
# eps = 0.11624983211768716
#  43208/50000: episode: 85, duration: 2.528s, episode steps: 1000, steps per second: 396, episode reward: 41.728, mean reward: 0.042 [-24.078, 22.883], mean action: 1.116 [0.000, 3.000], mean observation: 0.063 [-0.962, 1.426], loss: 5.255543, mean_absolute_error: 22.714888, mean_q: 28.815134
# eps = 0.11334358631474498
#  44208/50000: episode: 86, duration: 2.378s, episode steps: 1000, steps per second: 420, episode reward: -16.048, mean reward: -0.016 [-25.290, 21.885], mean action: 2.039 [0.000, 3.000], mean observation: 0.018 [-0.922, 1.410], loss: 4.966012, mean_absolute_error: 22.726023, mean_q: 28.671921
# eps = 0.11050999665687634
#  45208/50000: episode: 87, duration: 2.740s, episode steps: 1000, steps per second: 365, episode reward: -38.001, mean reward: -0.038 [-5.019, 4.589], mean action: 1.597 [0.000, 3.000], mean observation: -0.040 [-0.858, 1.400], loss: 5.540434, mean_absolute_error: 22.607655, mean_q: 28.554218
# eps = 0.10774724674045444
#  46208/50000: episode: 88, duration: 2.733s, episode steps: 1000, steps per second: 366, episode reward: 2.967, mean reward: 0.003 [-4.760, 5.180], mean action: 1.633 [0.000, 3.000], mean observation: -0.023 [-0.798, 1.411], loss: 5.748413, mean_absolute_error: 22.760771, mean_q: 28.779997
# eps = 0.10505356557194308
#  47208/50000: episode: 89, duration: 2.858s, episode steps: 1000, steps per second: 350, episode reward: -11.489, mean reward: -0.011 [-11.013, 12.805], mean action: 1.706 [0.000, 3.000], mean observation: -0.007 [-0.638, 1.457], loss: 4.119097, mean_absolute_error: 22.959831, mean_q: 29.431007
# eps = 0.1024272264326445
#  47629/50000: episode: 90, duration: 1.041s, episode steps: 421, steps per second: 405, episode reward: -28.845, mean reward: -0.069 [-100.000, 12.010], mean action: 1.682 [0.000, 3.000], mean observation: 0.020 [-0.509, 1.387], loss: 4.398177, mean_absolute_error: 23.018944, mean_q: 29.429831
# eps = 0.09986654577182838
#  48629/50000: episode: 91, duration: 2.616s, episode steps: 1000, steps per second: 382, episode reward: -38.888, mean reward: -0.039 [-4.775, 4.853], mean action: 1.426 [0.000, 3.000], mean observation: 0.002 [-0.445, 1.402], loss: 4.647063, mean_absolute_error: 23.114355, mean_q: 29.670671
# eps = 0.09736988212753267
#  49629/50000: episode: 92, duration: 2.982s, episode steps: 1000, steps per second: 335, episode reward: -43.257, mean reward: -0.043 [-4.954, 4.894], mean action: 1.919 [0.000, 3.000], mean observation: 0.123 [-0.377, 1.517], loss: 5.880149, mean_absolute_error: 22.855387, mean_q: 29.303530
# eps = 0.09493563507434435
# done, took 139.367 seconds
# Testing for 5 episodes ...
# Episode 1: reward: -27.403, steps: 1000
# Episode 2: reward: -6.164, steps: 1000
# Episode 3: reward: -29.506, steps: 1000
# Episode 4: reward: -15.568, steps: 1000
# Episode 5: reward: -28.386, steps: 1000
